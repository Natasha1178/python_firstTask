# %%
#Question1
#calculator App
num1 = int(input("Enter first Number"))
num2 = int(input("Enter Second Number"))
operator = input("Enter your Operator")

if operator == "+":
    print(num1+num2)
elif operator == "-":
    print(num1-num2)
elif operator == "/":
    print(num1/num2)
elif operator == "*":
    print(num1*num2)
else:
    print("invalid operator")
# Out:
# Enter first Number 40
# Enter Second Number 32
# Enter your Operator -
# 8

# %%
#Question2
my_list = ["apple", 5, "banana", "mango"]

for item in my_list:
    if type(item) == int or type(item) == float:
        print("The list contains a numeric value.")
        break
else:
    print("The list does not contain any numeric value.")
# Out:
# The list contains a numeric value.

# %%
#Question3
my_dict = {
    "name": "Natasha",
    "age": 22
}


my_dict["city"] = "Karachi"

print("Updated Dictionary:", my_dict)
# Out:
# Updated Dictionary: {'name': 'Natasha', 'age': 22, 'city': 'Karachi'}

# %%
#Question4
my_dict = {
    "a": 20,
    "b": 40,
    "c": 60
}

total = sum(my_dict.values())

print("Sum of all numeric values:", total)
# Out:
# Sum of all numeric values: 120

# %%
#Question5
my_list = [1, 2, 3, 6, 4, 5, 1, 6,4]

duplicates = []

for item in my_list:
    if my_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values are:", duplicates)
# Out:
# Duplicate values are: [1, 6, 4]

# %%
#Question6
my_dict = {
    "name": "Natasha",
    "age": 22,
    "city": "Karachi"
}

key = input("Enter key to check: ")

if key in my_dict:
    print("Key exists in the dictionary.")
else:
    print("Key does not exist in the dictionary.")
# Out:
# Enter key to check:  city
# Key exists in the dictionary.
